# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_dir="/Users/laurasansc/github/algorithms_bioinformatics/data/"

# %%
raw_data_file = data_dir + "predictions_smm.txt"

# %%
raw_data = pd.read_csv(raw_data_file, sep="\t")

# %%
raw_data
# Out:
#           species       allele  length  cv     sequence inequality  \
# 0      chimpanzee  Patr A*0901      11   0  ACISSEATTPV          =
# 1      chimpanzee  Patr A*0901      11   0  AQISSEATTPV          =
# 2      chimpanzee  Patr A*0901      11   0  ARISSEATTPV          =
# 3      chimpanzee  Patr A*0901      11   0  AYESSEATTPV          =
# 4      chimpanzee  Patr A*0901      11   0  AYFSSEATTPV          =
# ...           ...          ...     ...  ..          ...        ...
# 48823       mouse       H-2 Ld       9   4    SLSAYIIRV          >
# 48824       mouse       H-2 Ld       9   4    SPTVWLSVI          =
# 48825       mouse       H-2 Ld       9   4    SSYRRPVGI          >
# 48826       mouse       H-2 Ld       9   4    SYIPSAEKI          =
# 48827       mouse       H-2 Ld       9   4    YPHYMPTNL          =
#
#               ic50        smm
# 0        221.26100       53.8
# 1         41.18890       53.8
# 2        621.99800       53.8
# 3        421.11700      166.0
# 4         54.91940      166.0
# ...            ...        ...
# 48823  77142.90000    42442.4
# 48824  27000.00000     5071.3
# 48825  77142.90000  1717830.0
# 48826  30816.10000    30928.6
# 48827      9.64286       60.8
#
# [48828 rows x 8 columns]

# %%
raw_data['ic50'].hist(by=raw_data['species'])
# Out:
# /Users/laurasansc/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/laurasansc/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/laurasansc/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Users/laurasansc/Library/Python/3.7/lib/python/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113aba350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c46250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116525850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116557fd0>]],
#       dtype=object)

# %%
# Group by human
human_data = raw_data[raw_data['species'].isin(['human'])]

# %%
human_data
# Out:
#       species      allele  length  cv   sequence inequality        ic50  \
# 221     human  HLA A*0101       9   0  AANEIRISK          >  20000.0000
# 222     human  HLA A*0101       9   0  AEHDPWWAV          >  20000.0000
# 223     human  HLA A*0101       9   0  AEIDRSFKP          >  20000.0000
# 224     human  HLA A*0101       9   0  AFGLFWLVW          >  20000.0000
# 225     human  HLA A*0101       9   0  ALSMADIFI          >  20000.0000
# ...       ...         ...     ...  ..        ...        ...         ...
# 41528   human  HLA B*5801       9   4  YTDDYPMYK          >  20000.0000
# 41529   human  HLA B*5801       9   4  YTFCRLNVK          >  20000.0000
# 41530   human  HLA B*5801       9   4  YTFVVPLVY          =     65.1441
# 41531   human  HLA B*5801       9   4  YTSDYFISY          =   1139.0000
# 41532   human  HLA B*5801       9   4  YYYNFSEDL          >  20000.0000
#
#              smm
# 221      32211.4
# 222     640118.0
# 223    1030740.0
# 224     283674.0
# 225       9716.1
# ...          ...
# 41528    35298.0
# 41529    47527.0
# 41530       69.3
# 41531      800.8
# 41532     8458.8
#
# [41312 rows x 8 columns]

# %%
filtered_data = human_data.filter(lambda x: (x["ic50"] < 500))

# %%
filtered_data
# Out:
#       species      allele  length  cv   sequence inequality        ic50  \
# 221     human  HLA A*0101       9   0  AANEIRISK          >  20000.0000
# 222     human  HLA A*0101       9   0  AEHDPWWAV          >  20000.0000
# 223     human  HLA A*0101       9   0  AEIDRSFKP          >  20000.0000
# 224     human  HLA A*0101       9   0  AFGLFWLVW          >  20000.0000
# 225     human  HLA A*0101       9   0  ALSMADIFI          >  20000.0000
# ...       ...         ...     ...  ..        ...        ...         ...
# 41528   human  HLA B*5801       9   4  YTDDYPMYK          >  20000.0000
# 41529   human  HLA B*5801       9   4  YTFCRLNVK          >  20000.0000
# 41530   human  HLA B*5801       9   4  YTFVVPLVY          =     65.1441
# 41531   human  HLA B*5801       9   4  YTSDYFISY          =   1139.0000
# 41532   human  HLA B*5801       9   4  YYYNFSEDL          >  20000.0000
#
#              smm
# 221      32211.4
# 222     640118.0
# 223    1030740.0
# 224     283674.0
# 225       9716.1
# ...          ...
# 41528    35298.0
# 41529    47527.0
# 41530       69.3
# 41531      800.8
# 41532     8458.8
#
# [41312 rows x 8 columns]
